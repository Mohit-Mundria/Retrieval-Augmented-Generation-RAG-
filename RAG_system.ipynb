# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %%
from langchain_community.document_loaders import PyMuPDFLoader
from pathlib import Path

# %%
load_dotenv()
# Out:
# True

# %%
embeddings_model=GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite",temperature=0.3)

# %%
# paths=["D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\2bf1f0e9f04e6fb4f8fef35e82c42aa5.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\113_1803_21.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\186_2019_ls_eng_0.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\A2006-27.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\A187209.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\CERT-In_Directions_70B_28.04.2022.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\ir_gazette_of_india.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\it_amendment_act2008.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\IT-Intermediary-Rules-2021-updated-on-28.10.2022-2.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\itbill2000.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\Labour Act.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\list_of_important_sections__based__on_companies_act_with_complete_summary_of_companies_act_part_2.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\ss_code_gazette.pdf","D:\End to end project\End_to_End_Agentic+RAG_system\End_to_End_Agentic-RAG_system\Laws_dataset\the_code_on_wages_as_introduced.pdf"]
# documents=[]
# def load_docs(path):
#     docs=[]
#     for i in path:
#         i = i.replace("\\", "/")
#         i_obj = Path(i)

#     # Step 3 — Resolve to absolute path
#         i_obj.resolve()

#     # Step 4 — Convert to POSIX format (always safe)
#         i_obj.as_posix()
#         loader=PyMuPDFLoader(i_obj)
#         docs.append(loader.load())
#     return docs
# documents=load_docs(paths)
# documents

# %%
docs1=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\2bf1f0e9f04e6fb4f8fef35e82c42aa5.pdf")
docs2=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\113_1803_21.pdf")
docs3=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\186_2019_ls_eng_0.pdf")
docs4=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\A2006-27.pdf")
docs5=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\A187209.pdf")
docs6=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\CERT-In_Directions_70B_28.04.2022.pdf")
docs7=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\ir_gazette_of_india.pdf")
docs8=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\it_amendment_act2008.pdf")
docs9=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\IT-Intermediary-Rules-2021-updated-on-28.10.2022-2.pdf")
docs10=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\itbill2000.pdf")
docs11=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\Labour Act.pdf")
docs12=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\list_of_important_sections__based__on_companies_act_with_complete_summary_of_companies_act_part_2.pdf")
docs13=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\ss_code_gazette.pdf")
docs14=PyMuPDFLoader(r"D:\End to end project\End_to_End_Agentic+RAG_system\Laws_dataset\the_code_on_wages_as_introduced.pdf")

# %%
docs=[docs1,docs2,docs3,docs4,docs5,docs6,docs7,docs8,docs9,docs10,docs11,docs12,docs13,docs14]
documents=[]
for i in docs:
    documents.append(i.load())

documents = [d for sub in documents for d in sub]

# %%
len(documents)
# Out:
# 707

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=250,
    separators=["\n\nSECTION", "\n\nCHAPTER", "\n\n", "\n", " "]
)

texts=[d.page_content for d in documents]
metadatas=[d.metadata for d in documents]
chunks=splitter.create_documents(texts,metadatas)

vector_store=FAISS.from_documents(chunks, embeddings_model)

# %%
retriver=vector_store.as_retriever(search_type="similarity", search_kwargs={"k":15})
result=retriver.invoke("What are the labour laws in india")
result
# Out:
# [Document(id='8768dd54-8fb8-4dcc-9f01-b652ce148230', metadata={'producer': 'convertonlinefree.com', 'creator': 'convertonlinefree.com', 'creationdate': '2012-10-08T10:05:47+02:00', 'source': 'D:\\End to end project\\End_to_End_Agentic+RAG_system\\Laws_dataset\\Labour Act.pdf', 'file_path': 'D:\\End to end project\\End_to_End_Agentic+RAG_system\\Laws_dataset\\Labour Act.pdf', 'total_pages': 197, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2012-10-08T13:38:03+05:30', 'trapped': '', 'modDate': "D:20121008133803+05'30'", 'creationDate': "D:20121008100547+02'00'", 'page': 8}, page_content='rules. \n \n2. LABOUR LAWS IN INDIA \nThe term ‘labour’ means productive work especially physical work done for wages. Labour law also \nknown as employment law is the body of laws, administrative rulings, and precedents which address \nthe legal rights of, and restrictions on, working people and their organizations. There are two broad \ncategories of labo
# ...

# %%
def llm_response(ques:str)-> str:
    
    prompt=PromptTemplate(template="""You are a Law specified Assistant. Answer ONLY  from the provided Laws context. If the context is not sufficient then simply say don't know.
                        context : {content},
                        question : {question}""", input_variables=["content","question"])

    question=ques
    retrieved_docs=retriver.invoke(question)


    content="\n\n". join(doc.page_content for doc in retrieved_docs)
    final_prompt=prompt.invoke({'content':content, 'question':question})
    answer=model.invoke(final_prompt)
    return {"Answer is:":answer.content,"Retrieved Laws and Documents: ":retrieved_docs}

# %%
result=llm_response("Under the IT Amendment Act, what types of cyber offences are defined related to unauthorized access to computer systems?")
result
# Out:
# {'Answer is:': 'The IT Amendment Act defines the following types of cyber offenses related to unauthorized access to computer systems:\n\n*   **Accessing or securing access to a computer, computer system, or computer network without permission:** This is covered under Section 43(a).\n*   **Downloading, copying, or extracting data, computer databases, or information from a computer, computer system, or computer network, including information stored in removable media, without permission:** This is covered under Section 43(b).\n*   **Denying or causing the denial of access to any person authorized to access a computer, computer system, or computer network by any means:** This is covered under Section 43(f).\n*   **Providing assistance to any person to facilitate access to a computer, computer system, or computer network in contravention of the provisions of the Act, rules, or regulations:** This is covered under Section 43(g).\n*   **Securing access or attempting to secure access to a 
# ...
